# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from citipy import citipy
import requests

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    country_code =citipy.nearest_city(coordinate[0], coordinate[1]).country_code
        #wind=citipy.nearest_city(coordinate[0], coordinate[1]).wind_speed
      # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 720

# %%
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" +weather_api_key
#print(url)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data=[]

    

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 100 for logging purposes.
    if (i % 100 == 0 and i >= 100):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    try:
        # Parse the JSON and retrieve data.
      city_weather = requests.get(city_url).json()
       
        # Parse out the needed data.
      city_lat = city_weather["coord"]["lat"]
      city_lng = city_weather["coord"]["lon"]
      city_max_temp = city_weather["main"]["temp_max"]
      city_humidity = city_weather["main"]["humidity"]
      city_clouds = city_weather["clouds"]["all"]
      city_wind = city_weather["wind"]["speed"]
      city_weather_desc= city_weather["weather"][0]["description"]
      city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
      #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
      city_data.append({"City": city.title(),
                         "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                           "Current Description":city_weather_desc}                   
                          )
    except:
        print("City not found. Skipping...")
        pass
    # Add 1 to the record count.
    record_count += 1

    # Log the URL, record, and set numbers and the city.
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pontian kecil
# Processing Record 2 of Set 1 | ambilobe
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | krasnoye
# Processing Record 5 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | del rio
# Processing Record 9 of Set 1 | richards bay
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | saldanha
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | mecca
# Processing Record 16 of Set 1 | dingle
# Processing Record 17 of Set 1 | ancud
# Processing Record 18 of Set 1 | walvis bay
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | coos bay
# Processing Record 21 of Set 1 | henties bay
# Processing Record 22 of Set 1 | khed
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | dyersburg
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | boa vista
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | krutikha
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | kavieng
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | barra do garcas
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | arlit
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | bratsk
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | zhangye
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | pevek
# Processing Record 51 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 52 of Set 1 | luderitz
# Processing Record 53 of Set 1 | buldana
# Processing Record 54 of Set 1 | cape town
# Processing Record 55 of Set 1 | yellowknife
# Processing Record 56 of Set 1 | white rock
# Processing Record 57 of Set 1 | mount gambier
# Processing Record 58 of Set 1 | bredasdorp
# Processing Record 59 of Set 1 | bethel
# Processing Record 60 of Set 1 | thinadhoo
# Processing Record 61 of Set 1 | portland
# Processing Record 62 of Set 1 | ahumada
# City not found. Skipping...
# Processing Record 63 of Set 1 | juifang
# City not found. Skipping...
# Processing Record 64 of Set 1 | panaba
# Processing Record 65 of Set 1 | kodiak
# Processing Record 66 of Set 1 | saskylakh
# Processing Record 67 of Set 1 | nemuro
# Processing Record 68 of Set 1 | mao
# Processing Record 69 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 70 of Set 1 | taywarah
# Processing Record 71 of Set 1 | yar-sale
# Processing Record 72 of Set 1 | mataura
# Processing Record 73 of Set 1 | puerto colombia
# Processing Record 74 of Set 1 | constitucion
# Processing Record 75 of Set 1 | san patricio
# Processing Record 76 of Set 1 | burica
# City not found. Skipping...
# Processing Record 77 of Set 1 | hambantota
# Processing Record 78 of Set 1 | bata
# Processing Record 79 of Set 1 | jamestown
# Processing Record 80 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 81 of Set 1 | sorong
# Processing Record 82 of Set 1 | puerto carreno
# Processing Record 83 of Set 1 | poum
# Processing Record 84 of Set 1 | gazli
# Processing Record 85 of Set 1 | poya
# Processing Record 86 of Set 1 | sechura
# Processing Record 87 of Set 1 | hobart
# Processing Record 88 of Set 1 | sobolevo
# Processing Record 89 of Set 1 | dongsheng
# Processing Record 90 of Set 1 | havelock
# Processing Record 91 of Set 1 | arraial do cabo
# Processing Record 92 of Set 1 | carnarvon
# Processing Record 93 of Set 1 | avarua
# Processing Record 94 of Set 1 | saint-augustin
# Processing Record 95 of Set 1 | tasiilaq
# Processing Record 96 of Set 1 | santa maria
# Processing Record 97 of Set 1 | hithadhoo
# Processing Record 98 of Set 1 | paracuru
# Processing Record 99 of Set 1 | salekhard
# Processing Record 100 of Set 1 | adrar
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | itacare
# Processing Record 3 of Set 2 | inuvik
# Processing Record 4 of Set 2 | atar
# Processing Record 5 of Set 2 | chicama
# Processing Record 6 of Set 2 | nome
# Processing Record 7 of Set 2 | otautau
# Processing Record 8 of Set 2 | severo-kurilsk
# Processing Record 9 of Set 2 | havoysund
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | matara
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | nihommatsu
# Processing Record 14 of Set 2 | deer lake
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | port shepstone
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | port-cartier
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | damaturu
# Processing Record 21 of Set 2 | margate
# Processing Record 22 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 2 | vostok
# Processing Record 24 of Set 2 | alihe
# Processing Record 25 of Set 2 | hobyo
# Processing Record 26 of Set 2 | waingapu
# Processing Record 27 of Set 2 | bambous virieux
# Processing Record 28 of Set 2 | broome
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | pochutla
# Processing Record 33 of Set 2 | kilindoni
# Processing Record 34 of Set 2 | tromso
# Processing Record 35 of Set 2 | aksu
# Processing Record 36 of Set 2 | abu zabad
# Processing Record 37 of Set 2 | ginda
# Processing Record 38 of Set 2 | toila
# Processing Record 39 of Set 2 | norrtalje
# Processing Record 40 of Set 2 | lompoc
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | noumea
# Processing Record 45 of Set 2 | creel
# Processing Record 46 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 2 | micheweni
# Processing Record 48 of Set 2 | pangnirtung
# Processing Record 49 of Set 2 | tongchuan
# Processing Record 50 of Set 2 | talnakh
# Processing Record 51 of Set 2 | pingliang
# Processing Record 52 of Set 2 | porto novo
# Processing Record 53 of Set 2 | san carlos de bariloche
# Processing Record 54 of Set 2 | baghdad
# Processing Record 55 of Set 2 | liberty
# Processing Record 56 of Set 2 | pimentel
# Processing Record 57 of Set 2 | manokwari
# Processing Record 58 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 59 of Set 2 | khilok
# Processing Record 60 of Set 2 | mountain home
# Processing Record 61 of Set 2 | saint-louis
# Processing Record 62 of Set 2 | taoudenni
# Processing Record 63 of Set 2 | andros town
# Processing Record 64 of Set 2 | maun
# Processing Record 65 of Set 2 | itarema
# Processing Record 66 of Set 2 | les cayes
# Processing Record 67 of Set 2 | marsh harbour
# Processing Record 68 of Set 2 | bismil
# Processing Record 69 of Set 2 | kirov
# Processing Record 70 of Set 2 | haapu
# City not found. Skipping...
# Processing Record 71 of Set 2 | sitka
# Processing Record 72 of Set 2 | chuy
# Processing Record 73 of Set 2 | kiunga
# Processing Record 74 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 75 of Set 2 | coihaique
# Processing Record 76 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 77 of Set 2 | obukhiv
# Processing Record 78 of Set 2 | naze
# Processing Record 79 of Set 2 | lawrenceburg
# Processing Record 80 of Set 2 | vestnes
# Processing Record 81 of Set 2 | kahului
# Processing Record 82 of Set 2 | klaksvik
# Processing Record 83 of Set 2 | papagaios
# Processing Record 84 of Set 2 | alugan
# Processing Record 85 of Set 2 | udachnyy
# Processing Record 86 of Set 2 | ewa beach
# Processing Record 87 of Set 2 | khatanga
# Processing Record 88 of Set 2 | samarinda
# Processing Record 89 of Set 2 | parras
# City not found. Skipping...
# Processing Record 90 of Set 2 | coutances
# Processing Record 91 of Set 2 | eureka
# Processing Record 92 of Set 2 | souillac
# Processing Record 93 of Set 2 | port elizabeth
# Processing Record 94 of Set 2 | lomianki
# Processing Record 95 of Set 2 | provideniya
# Processing Record 96 of Set 2 | kabompo
# Processing Record 97 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 98 of Set 2 | tan an
# Processing Record 99 of Set 2 | luba
# Processing Record 100 of Set 2 | pangai
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | laguna
# Processing Record 3 of Set 3 | sur
# Processing Record 4 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 5 of Set 3 | monrovia
# Processing Record 6 of Set 3 | carutapera
# Processing Record 7 of Set 3 | aklavik
# Processing Record 8 of Set 3 | bayir
# Processing Record 9 of Set 3 | pisco
# Processing Record 10 of Set 3 | codrington
# Processing Record 11 of Set 3 | hirara
# Processing Record 12 of Set 3 | geraldton
# Processing Record 13 of Set 3 | kamaishi
# Processing Record 14 of Set 3 | cayenne
# Processing Record 15 of Set 3 | oranjemund
# Processing Record 16 of Set 3 | iqaluit
# Processing Record 17 of Set 3 | warri
# Processing Record 18 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 3 | havre-saint-pierre
# Processing Record 20 of Set 3 | vestmannaeyjar
# Processing Record 21 of Set 3 | nadadores
# Processing Record 22 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 3 | morozovsk
# Processing Record 24 of Set 3 | selma
# Processing Record 25 of Set 3 | kamloops
# Processing Record 26 of Set 3 | puerto del rosario
# Processing Record 27 of Set 3 | tawzar
# City not found. Skipping...
# Processing Record 28 of Set 3 | bouna
# Processing Record 29 of Set 3 | palana
# Processing Record 30 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 3 | hofn
# Processing Record 32 of Set 3 | clyde river
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | bud
# Processing Record 35 of Set 3 | sakakah
# Processing Record 36 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 3 | jalu
# Processing Record 38 of Set 3 | krasnyy chikoy
# Processing Record 39 of Set 3 | guerrero negro
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | bakaly
# Processing Record 42 of Set 3 | bambanglipuro
# Processing Record 43 of Set 3 | san juan del sur
# Processing Record 44 of Set 3 | wagar
# Processing Record 45 of Set 3 | ballina
# Processing Record 46 of Set 3 | saint-philippe
# Processing Record 47 of Set 3 | mount isa
# Processing Record 48 of Set 3 | alta gracia
# Processing Record 49 of Set 3 | fayaoue
# Processing Record 50 of Set 3 | hasaki
# Processing Record 51 of Set 3 | naryan-mar
# Processing Record 52 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 53 of Set 3 | mayor pablo lagerenza
# Processing Record 54 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 55 of Set 3 | kuusamo
# Processing Record 56 of Set 3 | skelleftea
# Processing Record 57 of Set 3 | yibin
# Processing Record 58 of Set 3 | santarem
# Processing Record 59 of Set 3 | tyukalinsk
# Processing Record 60 of Set 3 | touros
# Processing Record 61 of Set 3 | omegna
# Processing Record 62 of Set 3 | ilulissat
# Processing Record 63 of Set 3 | linchuan
# City not found. Skipping...
# Processing Record 64 of Set 3 | moroni
# Processing Record 65 of Set 3 | coquimbo
# Processing Record 66 of Set 3 | goma
# Processing Record 67 of Set 3 | lapa
# Processing Record 68 of Set 3 | pacific grove
# Processing Record 69 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 70 of Set 3 | orlik
# Processing Record 71 of Set 3 | ostrovnoy
# Processing Record 72 of Set 3 | kamenka
# Processing Record 73 of Set 3 | general pico
# Processing Record 74 of Set 3 | kologriv
# Processing Record 75 of Set 3 | batagay
# Processing Record 76 of Set 3 | lota
# Processing Record 77 of Set 3 | vinh long
# Processing Record 78 of Set 3 | himora
# City not found. Skipping...
# Processing Record 79 of Set 3 | college
# Processing Record 80 of Set 3 | khash
# Processing Record 81 of Set 3 | katangli
# Processing Record 82 of Set 3 | rexburg
# Processing Record 83 of Set 3 | xining
# Processing Record 84 of Set 3 | dubbo
# Processing Record 85 of Set 3 | fortuna
# Processing Record 86 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 87 of Set 3 | katsuura
# Processing Record 88 of Set 3 | manavalakurichi
# Processing Record 89 of Set 3 | buzmeyin
# Processing Record 90 of Set 3 | fairbanks
# Processing Record 91 of Set 3 | gorontalo
# Processing Record 92 of Set 3 | samba
# Processing Record 93 of Set 3 | niamey
# Processing Record 94 of Set 3 | alghero
# Processing Record 95 of Set 3 | swidwin
# Processing Record 96 of Set 3 | hamilton
# Processing Record 97 of Set 3 | byron bay
# Processing Record 98 of Set 3 | ngunguru
# Processing Record 99 of Set 3 | tyup
# Processing Record 100 of Set 3 | stromness
# Processing Record 1 of Set 4 | amapa
# Processing Record 2 of Set 4 | palaiokhora
# City not found. Skipping...
# Processing Record 3 of Set 4 | nampula
# Processing Record 4 of Set 4 | resistencia
# Processing Record 5 of Set 4 | tautira
# Processing Record 6 of Set 4 | svetlaya
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | avera
# Processing Record 9 of Set 4 | ovsyanka
# Processing Record 10 of Set 4 | port lincoln
# Processing Record 11 of Set 4 | shenjiamen
# Processing Record 12 of Set 4 | solwezi
# Processing Record 13 of Set 4 | nardaran
# Processing Record 14 of Set 4 | tura
# Processing Record 15 of Set 4 | hami
# Processing Record 16 of Set 4 | huarmey
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | cabo san lucas
# Processing Record 19 of Set 4 | inzhavino
# Processing Record 20 of Set 4 | kushima
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | awjilah
# Processing Record 23 of Set 4 | ridgecrest
# Processing Record 24 of Set 4 | krsko
# Processing Record 25 of Set 4 | kavaratti
# Processing Record 26 of Set 4 | buraydah
# Processing Record 27 of Set 4 | saint anthony
# Processing Record 28 of Set 4 | krasnoselkup
# Processing Record 29 of Set 4 | narwana
# Processing Record 30 of Set 4 | copacel
# Processing Record 31 of Set 4 | karuzi
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | carndonagh
# Processing Record 34 of Set 4 | praia da vitoria
# Processing Record 35 of Set 4 | winneba
# Processing Record 36 of Set 4 | leningradskiy
# Processing Record 37 of Set 4 | saint-pierre
# Processing Record 38 of Set 4 | chokurdakh
# Processing Record 39 of Set 4 | camacha
# Processing Record 40 of Set 4 | svetlogorsk
# Processing Record 41 of Set 4 | san quintin
# Processing Record 42 of Set 4 | kalininsk
# Processing Record 43 of Set 4 | nalut
# Processing Record 44 of Set 4 | bereda
# Processing Record 45 of Set 4 | turbo
# Processing Record 46 of Set 4 | pechenga
# Processing Record 47 of Set 4 | fredericton
# Processing Record 48 of Set 4 | tabat
# Processing Record 49 of Set 4 | yucca valley
# Processing Record 50 of Set 4 | susangerd
# Processing Record 51 of Set 4 | nakhon phanom
# Processing Record 52 of Set 4 | senador pompeu
# Processing Record 53 of Set 4 | labuhan
# Processing Record 54 of Set 4 | lagos
# Processing Record 55 of Set 4 | khandyga
# Processing Record 56 of Set 4 | salinas
# Processing Record 57 of Set 4 | akyab
# Processing Record 58 of Set 4 | santa isabel
# Processing Record 59 of Set 4 | maceio
# Processing Record 60 of Set 4 | san luis
# Processing Record 61 of Set 4 | bridlington
# Processing Record 62 of Set 4 | ushumun
# Processing Record 63 of Set 4 | port augusta
# Processing Record 64 of Set 4 | faya
# Processing Record 65 of Set 4 | beira
# Processing Record 66 of Set 4 | boguchany
# Processing Record 67 of Set 4 | eenhana
# Processing Record 68 of Set 4 | celestun
# Processing Record 69 of Set 4 | carupano
# Processing Record 70 of Set 4 | khristoforovo
# City not found. Skipping...
# Processing Record 71 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 72 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 73 of Set 4 | lamu
# Processing Record 74 of Set 4 | pasni
# Processing Record 75 of Set 4 | husavik
# Processing Record 76 of Set 4 | iquitos
# Processing Record 77 of Set 4 | namibe
# Processing Record 78 of Set 4 | flinders
# Processing Record 79 of Set 4 | isangel
# Processing Record 80 of Set 4 | reconquista
# Processing Record 81 of Set 4 | salalah
# Processing Record 82 of Set 4 | jutiapa
# Processing Record 83 of Set 4 | carmen
# Processing Record 84 of Set 4 | bathsheba
# Processing Record 85 of Set 4 | port hedland
# Processing Record 86 of Set 4 | sigiriya
# Processing Record 87 of Set 4 | aloleng
# Processing Record 88 of Set 4 | ahipara
# Processing Record 89 of Set 4 | almaty
# Processing Record 90 of Set 4 | tessalit
# Processing Record 91 of Set 4 | inhambane
# Processing Record 92 of Set 4 | bestobe
# Processing Record 93 of Set 4 | pandan
# Processing Record 94 of Set 4 | bobrov
# Processing Record 95 of Set 4 | davila
# Processing Record 96 of Set 4 | road town
# Processing Record 97 of Set 4 | jasper
# Processing Record 98 of Set 4 | viedma
# Processing Record 99 of Set 4 | solnechnyy
# Processing Record 100 of Set 4 | te anau
# Processing Record 1 of Set 5 | tucuman
# Processing Record 2 of Set 5 | farmington
# Processing Record 3 of Set 5 | balakhta
# Processing Record 4 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 5 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 5 | porto velho
# Processing Record 7 of Set 5 | acapulco
# Processing Record 8 of Set 5 | vardo
# Processing Record 9 of Set 5 | lomovka
# Processing Record 10 of Set 5 | goure
# Processing Record 11 of Set 5 | liuli
# Processing Record 12 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 13 of Set 5 | howell
# Processing Record 14 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 15 of Set 5 | mitsamiouli
# Processing Record 16 of Set 5 | skogn
# Processing Record 17 of Set 5 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 18 of Set 5 | rio claro
# Processing Record 19 of Set 5 | kurya
# Processing Record 20 of Set 5 | wattegama
# Processing Record 21 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 5 | lakatoro
# Processing Record 23 of Set 5 | tuy hoa
# Processing Record 24 of Set 5 | cabra
# Processing Record 25 of Set 5 | ternate
# Processing Record 26 of Set 5 | leh
# Processing Record 27 of Set 5 | matagami
# Processing Record 28 of Set 5 | ziway
# Processing Record 29 of Set 5 | namatanai
# Processing Record 30 of Set 5 | maningrida
# Processing Record 31 of Set 5 | pasighat
# Processing Record 32 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 34 of Set 5 | healdsburg
# Processing Record 35 of Set 5 | aswan
# Processing Record 36 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 5 | muisne
# Processing Record 38 of Set 5 | los llanos de aridane
# Processing Record 39 of Set 5 | olbernhau
# Processing Record 40 of Set 5 | zwedru
# Processing Record 41 of Set 5 | lavrentiya
# Processing Record 42 of Set 5 | pau dos ferros
# Processing Record 43 of Set 5 | yizheng
# Processing Record 44 of Set 5 | oktyabrskiy
# Processing Record 45 of Set 5 | mangrol
# Processing Record 46 of Set 5 | port hawkesbury
# Processing Record 47 of Set 5 | san miguel
# Processing Record 48 of Set 5 | dahra
# Processing Record 49 of Set 5 | vila velha
# Processing Record 50 of Set 5 | porto belo
# Processing Record 51 of Set 5 | half moon bay
# Processing Record 52 of Set 5 | mirina
# City not found. Skipping...
# Processing Record 53 of Set 5 | vung tau
# Processing Record 54 of Set 5 | ventnor city
# Processing Record 55 of Set 5 | puri
# Processing Record 56 of Set 5 | mponela
# Processing Record 57 of Set 5 | dolores
# Processing Record 58 of Set 5 | loandjili
# Processing Record 59 of Set 5 | flin flon
# Processing Record 60 of Set 5 | necochea
# Processing Record 61 of Set 5 | dragu
# Processing Record 62 of Set 5 | sambava
# Processing Record 63 of Set 5 | mariental
# Processing Record 64 of Set 5 | gat
# Processing Record 65 of Set 5 | pietersburg
# Processing Record 66 of Set 5 | sao filipe
# Processing Record 67 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 68 of Set 5 | yumen
# Processing Record 69 of Set 5 | cozumel
# Processing Record 70 of Set 5 | mogadishu
# Processing Record 71 of Set 5 | andselv
# City not found. Skipping...
# Processing Record 72 of Set 5 | kawalu
# Processing Record 73 of Set 5 | ratnagiri
# Processing Record 74 of Set 5 | mandurah
# Processing Record 75 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 76 of Set 5 | beloha
# Processing Record 77 of Set 5 | iwanai
# Processing Record 78 of Set 5 | miyako
# Processing Record 79 of Set 5 | voiron
# Processing Record 80 of Set 5 | lata
# Processing Record 81 of Set 5 | vila
# Processing Record 82 of Set 5 | asau
# Processing Record 83 of Set 5 | bandarbeyla
# Processing Record 84 of Set 5 | kailua
# Processing Record 85 of Set 5 | cobija
# Processing Record 86 of Set 5 | pokanayevka
# City not found. Skipping...
# Processing Record 87 of Set 5 | eskisehir
# Processing Record 88 of Set 5 | elmira
# Processing Record 89 of Set 5 | tilichiki
# Processing Record 90 of Set 5 | goderich
# Processing Record 91 of Set 5 | soyo
# Processing Record 92 of Set 5 | padang
# Processing Record 93 of Set 5 | encruzilhada
# Processing Record 94 of Set 5 | mahon
# Processing Record 95 of Set 5 | kulhudhuffushi
# Processing Record 96 of Set 5 | waitati
# Processing Record 97 of Set 5 | tutoia
# Processing Record 98 of Set 5 | kalmar
# Processing Record 99 of Set 5 | porosozero
# Processing Record 100 of Set 5 | casablanca
# Processing Record 1 of Set 6 | kaitangata
# Processing Record 2 of Set 6 | marawi
# Processing Record 3 of Set 6 | kaltasy
# Processing Record 4 of Set 6 | llanes
# Processing Record 5 of Set 6 | kanniyakumari
# Processing Record 6 of Set 6 | aljezur
# Processing Record 7 of Set 6 | auch
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | tuatapere
# Processing Record 10 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 6 | salinopolis
# Processing Record 12 of Set 6 | grenfell
# Processing Record 13 of Set 6 | marrakesh
# Processing Record 14 of Set 6 | brae
# Processing Record 15 of Set 6 | kibre mengist
# Processing Record 16 of Set 6 | mayo
# Processing Record 17 of Set 6 | iquique
# Processing Record 18 of Set 6 | fevik
# Processing Record 19 of Set 6 | comodoro rivadavia
# Processing Record 20 of Set 6 | copiapo
# Processing Record 21 of Set 6 | sao jose da coroa grande
# Processing Record 22 of Set 6 | ixtapa
# Processing Record 23 of Set 6 | matane
# Processing Record 24 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 25 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 26 of Set 6 | antofagasta
# Processing Record 27 of Set 6 | rocha
# Processing Record 28 of Set 6 | bandundu
# Processing Record 29 of Set 6 | coffs harbour
# Processing Record 30 of Set 6 | lumby
# Processing Record 31 of Set 6 | alyangula
# Processing Record 32 of Set 6 | toamasina
# Processing Record 33 of Set 6 | santa lucia
# Processing Record 34 of Set 6 | cururupu
# Processing Record 35 of Set 6 | bonavista
# Processing Record 36 of Set 6 | sorland
# Processing Record 37 of Set 6 | kokoda
# Processing Record 38 of Set 6 | hibbing
# Processing Record 39 of Set 6 | shelburne
# Processing Record 40 of Set 6 | yerbogachen
# Processing Record 41 of Set 6 | funchal
# Processing Record 42 of Set 6 | virginia beach
# Processing Record 43 of Set 6 | susehri
# Processing Record 44 of Set 6 | syracuse
# Processing Record 45 of Set 6 | shimoda
# Processing Record 46 of Set 6 | north battleford
# Processing Record 47 of Set 6 | mattru
# Processing Record 48 of Set 6 | honningsvag
# Processing Record 49 of Set 6 | kalaiya
# Processing Record 50 of Set 6 | sanmenxia
# Processing Record 51 of Set 6 | champerico
# Processing Record 52 of Set 6 | komsomolskiy
# Processing Record 53 of Set 6 | mayumba
# Processing Record 54 of Set 6 | raudeberg
# Processing Record 55 of Set 6 | longyearbyen
# Processing Record 56 of Set 6 | kembe
# Processing Record 57 of Set 6 | belaya gora
# Processing Record 58 of Set 6 | broken hill
# Processing Record 59 of Set 6 | nantucket
# Processing Record 60 of Set 6 | verkhnevilyuysk
# Processing Record 61 of Set 6 | eydhafushi
# Processing Record 62 of Set 6 | gisborne
# Processing Record 63 of Set 6 | dhidhdhoo
# Processing Record 64 of Set 6 | ayotzingo
# City not found. Skipping...
# Processing Record 65 of Set 6 | umm lajj
# Processing Record 66 of Set 6 | george
# Processing Record 67 of Set 6 | karpathos
# Processing Record 68 of Set 6 | lengshuitan
# Processing Record 69 of Set 6 | manzhouli
# Processing Record 70 of Set 6 | muravlenko
# Processing Record 71 of Set 6 | kamen-na-obi
# Processing Record 72 of Set 6 | roald
# Processing Record 73 of Set 6 | wanaka
# Processing Record 74 of Set 6 | ulladulla
# Processing Record 75 of Set 6 | bengkulu
# Processing Record 76 of Set 6 | ati
# Processing Record 77 of Set 6 | snezhnogorsk
# Processing Record 78 of Set 6 | amalapuram
# Processing Record 79 of Set 6 | volchansk
# Processing Record 80 of Set 6 | axim
# Processing Record 81 of Set 6 | nouadhibou
# Processing Record 82 of Set 6 | palmer
# Processing Record 83 of Set 6 | sinnamary
# Processing Record 84 of Set 6 | yakeshi
# Processing Record 85 of Set 6 | kurchum
# Processing Record 86 of Set 6 | oytal
# Processing Record 87 of Set 6 | hualmay
# Processing Record 88 of Set 6 | staritsa
# Processing Record 89 of Set 6 | buchanan
# Processing Record 90 of Set 6 | pereleshino
# Processing Record 91 of Set 6 | tarbagatay
# Processing Record 92 of Set 6 | fandriana
# Processing Record 93 of Set 6 | xucheng
# Processing Record 94 of Set 6 | x-can
# City not found. Skipping...
# Processing Record 95 of Set 6 | yulara
# Processing Record 96 of Set 6 | malartic
# Processing Record 97 of Set 6 | vanavara
# Processing Record 98 of Set 6 | otane
# Processing Record 99 of Set 6 | rantoul
# Processing Record 100 of Set 6 | skibbereen
# Processing Record 1 of Set 7 | maki
# Processing Record 2 of Set 7 | xalpatlahuac
# Processing Record 3 of Set 7 | shush
# Processing Record 4 of Set 7 | komatsu
# Processing Record 5 of Set 7 | bukachacha
# Processing Record 6 of Set 7 | malatya
# Processing Record 7 of Set 7 | shubarshi
# Processing Record 8 of Set 7 | khasan
# Processing Record 9 of Set 7 | kieta
# Processing Record 10 of Set 7 | minab
# Processing Record 11 of Set 7 | ayr
# Processing Record 12 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 13 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 7 | ascension
# Processing Record 15 of Set 7 | linjiang
# Processing Record 16 of Set 7 | kapoeta
# Processing Record 17 of Set 7 | ojinaga
# Processing Record 18 of Set 7 | sao paulo de olivenca
# Processing Record 19 of Set 7 | zyryanka
# Processing Record 20 of Set 7 | rognan
# Processing Record 21 of Set 7 | rafaela
# Processing Record 22 of Set 7 | thessalon
# Processing Record 23 of Set 7 | praia
# Processing Record 24 of Set 7 | baruun-urt
# Processing Record 25 of Set 7 | teguldet
# Processing Record 26 of Set 7 | katsina
# Processing Record 27 of Set 7 | plettenberg bay
# Processing Record 28 of Set 7 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 29 of Set 7 | quebradillas
# Processing Record 30 of Set 7 | williams lake
# Processing Record 31 of Set 7 | isa khel
# Processing Record 32 of Set 7 | nyeri
# Processing Record 33 of Set 7 | grindavik
# Processing Record 34 of Set 7 | panacan
# Processing Record 35 of Set 7 | caravelas
# Processing Record 36 of Set 7 | samarai
# Processing Record 37 of Set 7 | hurghada
# Processing Record 38 of Set 7 | berck
# Processing Record 39 of Set 7 | thurles
# Processing Record 40 of Set 7 | moerai
# Processing Record 41 of Set 7 | filadelfia
# Processing Record 42 of Set 7 | nara
# Processing Record 43 of Set 7 | ryki
# Processing Record 44 of Set 7 | belgrade
# Processing Record 45 of Set 7 | sungurlare
# Processing Record 46 of Set 7 | fare
# Processing Record 47 of Set 7 | gander
# Processing Record 48 of Set 7 | cedar city
# Processing Record 49 of Set 7 | banamba
# Processing Record 50 of Set 7 | wells
# Processing Record 51 of Set 7 | beyneu
# Processing Record 52 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 53 of Set 7 | westport
# Processing Record 54 of Set 7 | paita
# Processing Record 55 of Set 7 | nioro
# Processing Record 56 of Set 7 | sergeyevka
# Processing Record 57 of Set 7 | nangong
# Processing Record 58 of Set 7 | ugoofaaru
# Processing Record 59 of Set 7 | baltay
# Processing Record 60 of Set 7 | ust-nera
# Processing Record 61 of Set 7 | kaduna
# Processing Record 62 of Set 7 | xinpu
# Processing Record 63 of Set 7 | shihezi
# Processing Record 64 of Set 7 | port macquarie
# Processing Record 65 of Set 7 | tabulbah
# City not found. Skipping...
# Processing Record 66 of Set 7 | a
# City not found. Skipping...
# Processing Record 67 of Set 7 | beni
# Processing Record 68 of Set 7 | aguas vermelhas
# Processing Record 69 of Set 7 | georgiyevka
# Processing Record 70 of Set 7 | sawakin
# Processing Record 71 of Set 7 | nanakuli
# Processing Record 72 of Set 7 | anadyr
# Processing Record 73 of Set 7 | morki
# Processing Record 74 of Set 7 | cerrito
# Processing Record 75 of Set 7 | nagato
# Processing Record 76 of Set 7 | lagoa
# Processing Record 77 of Set 7 | mareeba
# Processing Record 78 of Set 7 | balikpapan
# Processing Record 79 of Set 7 | meulaboh
# Processing Record 80 of Set 7 | koumac
# Processing Record 81 of Set 7 | namtsy
# Processing Record 82 of Set 7 | jega
# Processing Record 83 of Set 7 | port hardy
# Processing Record 84 of Set 7 | xuddur
# Processing Record 85 of Set 7 | antalaha
# Processing Record 86 of Set 7 | fort nelson
# Processing Record 87 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 88 of Set 7 | cleethorpes
# Processing Record 89 of Set 7 | ouesso
# Processing Record 90 of Set 7 | rudnogorsk
# Processing Record 91 of Set 7 | kantang
# Processing Record 92 of Set 7 | port said
# Processing Record 93 of Set 7 | porangatu
# Processing Record 94 of Set 7 | matay
# Processing Record 95 of Set 7 | guilin
# Processing Record 96 of Set 7 | cockburn town
# Processing Record 97 of Set 7 | biasca
# Processing Record 98 of Set 7 | salym
# Processing Record 99 of Set 7 | astipalaia
# City not found. Skipping...
# Processing Record 100 of Set 7 | algiers
# Processing Record 1 of Set 8 | tefe
# Processing Record 2 of Set 8 | samandag
# Processing Record 3 of Set 8 | dahegam
# Processing Record 4 of Set 8 | calama
# Processing Record 5 of Set 8 | nhulunbuy
# Processing Record 6 of Set 8 | sokur
# Processing Record 7 of Set 8 | berlevag
# Processing Record 8 of Set 8 | huambo
# Processing Record 9 of Set 8 | loviisa
# Processing Record 10 of Set 8 | kununurra
# Processing Record 11 of Set 8 | sorata
# Processing Record 12 of Set 8 | la sarre
# Processing Record 13 of Set 8 | kyshtovka
# Processing Record 14 of Set 8 | norman wells
# Processing Record 15 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 16 of Set 8 | northam
# Processing Record 17 of Set 8 | oriximina
# Processing Record 18 of Set 8 | santa vitoria do palmar
# Processing Record 19 of Set 8 | teya
# Processing Record 20 of Set 8 | koygorodok

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Pontian Kecil      MY   1.4801  103.3899     78.93        82          98
# 1        Ambilobe      MG -13.2000   49.0500     67.91        83           9
# 2        Krasnoye      UA  49.9145   24.6134     51.19        56          14
# 3    Punta Arenas      CL -53.1500  -70.9167     44.71        57           0
# 4  Ribeira Grande      PT  38.5167  -28.7000     71.83        89          24
# 5         Del Rio      US  29.3627 -100.8968     89.71        49           1
# 6    Richards Bay      ZA -28.7830   32.0377     58.21        84         100
# 7          Barrow      US  71.2906 -156.7887     28.42        86          90
# 8         Ushuaia      AR -54.8000  -68.3000     40.66        75          75
# 9         Rikitea      PF -23.1203 -134.9692     73.69        63          79
#
#    Wind Speed Current Description
# 0        1.63     overcast clouds
# 1        3.47           clear sky
# 2       11.52          few clouds
# 3       34.52           clear sky
# 4        6.46          few clouds
# 5        0.00           clear sky
# 6        5.23          light rain
# 7       16.11                mist
# 8       36.82          light rain
# 9       15.79       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
